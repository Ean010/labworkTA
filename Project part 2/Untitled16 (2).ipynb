# %%
# Import pandas
import pandas as pd

# Load the dataset
file_path = "Burger_reviews_combined_tripadvisor_googlereview_finalized.csv"
df = pd.read_csv(file_path)

# Show available columns
print("Available columns:", df.columns.tolist())
# Out:
# Available columns: ['place_name', 'tokenized']

# %%
pd.set_option('display.max_colwidth', None)  # Set to None for unlimited width

print(df)
# Out:
#              place_name  \
# 0            Mean Mince
# 1            Mean Mince
# 2            Mean Mince
# 3            Mean Mince
# 4            Mean Mince
# ...                 ...
# 1121      Spades Burger
# 1122      Spades Burger
# 1123      Spades Burger
# 1124      Spades Burger
# 1125  Woodfire Kl @ttdi
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tokenized
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['Love', 'double', 'smash', 'burger', 'bun', 'soft', 'patty', 'crisp', 'still', 'juicy', 'great', 'flavor', 'overall', 'philly', 'cheesesteak', 'also', 'good', 'generous', 'portion', 'pizza', 'also', 'generous', 'top', 'cheese', 'milkshake', 'also', 'thick', 'water', 'like', 'place', 'aunt', 'run', 'place', 'super', 'friendly', 'Accommodating', 'parking', 'also', 'plentified', 'make', 'super', 'plus', 'point', 'excellent', 'food', 'excellent', 'service', 'good', 'atmosphere']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ['lovely', 'time', 'burger', 'buffalo', 'wing', 'spider', 'year', 'old', 'super', 'time', 'try', 'mini', 'burger', 'run', 'family', 'really', 'friendly', 'food', 'freshly', 'prepare', 'definitely', 'recommend', 'excellent', 'food', 'excellent', 'service', 'explellent', 'atmospere']
# 2     ['always', 'love', 'Bon', 'Kovi', 'play', 'Speakers', 'push', 'door', 'open', 'enter', 'mean', 'American', 'concept', 'restaurant', 'serve', 'burger', 'sandwich', 'milkshake', 'dish', 'Tiara', 'Damansara', 'Chef', 'min', 'study', 'culinary', 'work', 'experience', 'locally', 'abroad', 'decide', 'Open', 'mean', 'Since', 'serve', 'heart', 'food', 'meat', 'Loving', 'people', 'creation', 'deep', 'fry', 'burger', 'beaten', 'like', 'myburgerlab', 'define', 'burger', 'town', 'burger', 'fest', 'reason', 'visit', 'deep', 'fri', 'burger', 'ugly', 'wrap', 'special', 'bread', 'dough', 'g', 'mean', 'mine', 'patty', 'choiceof', 'either', 'beef', 'chicken', 'nest', 'caramelised', 'onion', 'top', 'healthy', 'help', 'melt', 'mozzarella', 'cheese', 'patty', 'good', 'juicy', 'juice', 'spill', 'bite', 'excellent', 'stuff', 'patty', 'melt', 'sandwich', 'bread', 'grill', 'cheese', 'house', 'chicken', 'beef', 'serve', 'pasteand', 'tomato', 'salsa', 'grill', 'cheese', 'add', 'good', 'story', 'touch', 'chicken', 'sandwich', 'chill', 'cheese', 'fry', 'serve', 'stainless', 'steel', 'latter', 'bed', 'fry', 'top', 'bolognese', 'style', 'chicken', 'melt', 'cheese', 'hit', 'young', 'one', 'couldnt', 'resist', 'take', 'Jalapeno', 'Peppers', 'leaded.peppers', 'stuff', 'spicy', 'cream', 'cheese', 'piece', 'price', 'side', 'make', 'good', 'version', 'spider', 'x', 'g', 'house', 'beef', 'patty', 'baby', 'run', 'melt', 'American', 'slice', 'cheese', 'top', 'pickle', 'red', 'onion', 'caramelise', 'onion', 'mustard', 'mayo', 'easy', 'kid', 'grab', 'Peanut', 'Butter', 'Milkshake', 'cant', 'get', 'American', 'classic', 'milkshake', 'like', 'burger', 'lover', 'deep', 'fried', 'burger', 'alone', 'could', 'warrant', 'trip', 'mean', 'since', 'member', 'family', 'eye', 'chicago', 'style', 'deep', 'dish', 'pizza', 'well', 'variation', 'burger', 'subsequent', 'visit', 'Excellent', 'Food', 'Excellent', 'Service', 'Good', 'Atmosphere', 'Recommended', 'Dishes', 'Chill', 'Cheese', 'Fries']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ['look', 'rustic', 'nonsense', 'type', 'western', 'burger', 'reach', 'cheese', 'sauce', 'definitely', 'place', 'go', 'good', 'quality', 'meat', 'fluffy', 'roche', 'run', 'onion', 'ring', 'also', 'make', 'actual', 'proper', 'onion', 'process', 'pack', 'one', 'really', 'enjoyed', 'smash', 'definitely', 'back', 'try', 'philly', 'cheesesteak', 'excellent', 'food', 'excellent', 'service', 'good', 'atmosphere']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ['burger', 'restaurant', 'locate', 'Tiara', 'Damansara', 'service', 'atmosphere', 'excellent', 'owner', 'personally', 'provide', 'great', 'service', 'patiently', 'introduce', 'signature', 'burger', 'main', 'dish', 'focus', 'burger', 'offer', 'great', 'selection', 'especially', 'love', 'innovation', 'bring', 'burger', 'Quality', 'meat', 'pair', 'soft', 'roche', 'run', 'onion', 'ring', 'make', 'real', 'onion', 'process', 'package', 'one', 'try', 'different', 'burger', 'create', 'rich', 'flavor', 'profile', 'also', 'order', 'peanut', 'butter', 'shake', 'taste', 'interest', 'sound', 'odd', 'super', '-flavorful', 'drink', 'Also', 'try', 'strawberry', 'milkshake', 'coke', 'float', 'here', "'s", 'ordered', 'burger', 'spider', 'Deep', 'Fried', 'Burger', 'Chi', 'Mean', 'Church', 'Peanut', 'Butter', 'Shake', 'Strawberry', 'Shake', 'Coke', 'Float', 'Overall', 'Rating', 'Food', 'Service', 'Audience', 'Excellent', 'Food', 'Excellent', 'Service', 'Good', 'Atmosphere', 'Recommended', 'Dishes', 'Beef', 'Burger']
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 1121                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ['spade', '’', 's', 'pork', 'party', 'tasty', 'especially', 'like', 'cook', 'cheese', 'burger', 'make', 'go', 'burger', 'place', 'choose', 'burger', 'without', 'bun', 'wrap', 'lettuce', 'instead', 'must', 'try', 'love', 'pork', 'burger', 'read']
# 1122                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['first', 'time', 'taste', 'ipo', 'second', 'time', 'open', 'outlet', 's', 'sung', 'jay', 'although', 'kl', 'close', 'enough', 'staff', 'friendly', 'helpful', 'takeaway', 'time', 'place', 'easy', 'look', 'park', 'ordered', 'signature', 'big', 'burger', 'call', 'burger', 'steel', 'dozen', 'pocket', 'dozen', 'fry', 'bacon', 'strip', 'lunch', 'time', 'customer', 'din', 'pocket', 'actually', 'pork', 'nugget', 'item', 'order', 'really', 'good', 'come', 'back', 'surreal']
# 1123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['walk', 'pm', 'january', 'chinese', 'girl', 'counter', 'roll', 'eye', 'walk', 'away', 'check', 'huge', 'menu', 'wall', 'guy', 'come', 'cashier', 'stare', 'u', 'rude', 'facial', 'expression', 'order', 'burger', 'sound', 'really', 'unhappy', 'seriously', 'unhappy', 'come', 'late', 'hour', 'order', 'want', 'widely', 'ask', 'u', '“', 'what', 'combo', 'want', '”', 'mouth', 'cover', 'black', 'mask', 'really', 'hard', 'understand', 'say', 'ask', 'repeat', 'say', 'widely', 'ask', '“', 'what', 'combo', 'want', '”', 'want', 'piss', 'order', '“', 'all', 'pork', 'fine', '”', 'say', 'ask', 'u', 'another', 'question', 'combo', 'point', 'tv', 'menu', 'rally', 'rude', 'tone', 'st', 'it', '’', 's', 'break', 'hard', 'hear', 'mouth', 'cover', 'black', 'mask', 'nd', 'it', '’', 's', 'hard', 'understand', 'english', 'especially', 'sounded', 'angry', 'rd', 'it', '’', 's', 'close', 'disturb', 'closing', 'time', 'tel', 'u', 'it', '’', 's', 'close', 'win', '’', 't', 'torture', 'staff', 'rudeness', 'r', 'eat', 'free', 'didn', '’', 't', 'ask', 'anything', 'free', 'understand', 'rude', 'customer', 'also', 'retail', 'business', 'funny', 'thing', 'even', 'rude', 'worry', 'even', 'upset', 'can', 'not', 'handle', 'anymore', 'customer', 'put', 'closed', 'sign', 'read']
# 1124                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['non', 'halal', 'version', 'myburgerlab', 'opinion', 'gorgeous', 'ensemble', 'much', 'beauty', 'flavour', 'every', 'bite', 'regret', 'read']
# 1125                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['simple', 'decor', 'burger', 'joint', 'ttda', 'plaza', 'work', 'like', 'fast', 'food', 'joint', 'order', 'pay', 'wait', 'food', 'place', 'clean', 'service', 'friendly', 'order', 'beef', 'chicken', 'burger', 'surprise', 'burger', 'come', 'fry', 'fry', 'need', 'buy', 'separately', 'find', 'burger', 'tasty', 'money', 'sauce', 'delicious', 'side', 'also', 'compliment', 'burger', 'party', 'cook', 'well', 'chicken', 'crisp', 'outer', 'pretty', 'enjoyable', 'burger', 'mind', 'pay', 'extra', 'fry', 'read']
#
# [1126 rows x 2 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
# Function to calculate VADER sentiment scores
def vader_sentiment(text):
    return analyzer.polarity_scores(text)

# Apply VADER sentiment analysis to the 'tokenized' column and store the results
vader_scores = df['tokenized'].apply(vader_sentiment)

# Expand the dictionary returned by VADER into separate columns
df_vader = pd.json_normalize(vader_scores)

# %%
# Add the original 'place_name' and 'tokenized' columns
df_vader['place_name'] = df['place_name']
df_vader['tokenized'] = df['tokenized']

# %%
# Assign sentiment labels based on the compound score
def get_sentiment_label(compound_score):
    if compound_score >= 0.05:
        return 'positive'
    elif compound_score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

df_vader['sentiment_label'] = df_vader['compound'].apply(get_sentiment_label)

# %%
df_vader['sentiment_label'] = df_vader['compound'].apply(get_sentiment_label)

# Reorder the columns to match the desired order
df_vader = df_vader[['place_name', 'tokenized', 'compound', 'pos', 'neu', 'neg', 'sentiment_label']]

# %%
# Show a preview of the results
print(df_vader[['place_name', 'tokenized', 'compound', 'pos', 'neu', 'neg', 'sentiment_label']].head())
# Out:
#    place_name  \
# 0  Mean Mince
# 1  Mean Mince
# 2  Mean Mince
# 3  Mean Mince
# 4  Mean Mince
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              tokenized  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ['Love', 'double', 'smash', 'burger', 'bun', 'soft', 'patty', 'crisp', 'still', 'juicy', 'great', 'flavor', 'overall', 'philly', 'cheesesteak', 'also', 'good', 'generous', 'portion', 'pizza', 'also', 'generous', 'top', 'cheese', 'milkshake', 'also', 'thick', 'water', 'like', 'place', 'aunt', 'run', 'place', 'super', 'friendly', 'Accommodating', 'parking', 'also', 'plentified', 'make', 'super', 'plus', 'point', 'excellent', 'food', 'excellent', 'service', 'good', 'atmosphere']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['lovely', 'time', 'burger', 'buffalo', 'wing', 'spider', 'year', 'old', 'super', 'time', 'try', 'mini', 'burger', 'run', 'family', 'really', 'friendly', 'food', 'freshly', 'prepare', 'definitely', 'recommend', 'excellent', 'food', 'excellent', 'service', 'explellent', 'atmospere']
# 2  ['always', 'love', 'Bon', 'Kovi', 'play', 'Speakers', 'push', 'door', 'open', 'enter', 'mean', 'American', 'concept', 'restaurant', 'serve', 'burger', 'sandwich', 'milkshake', 'dish', 'Tiara', 'Damansara', 'Chef', 'min', 'study', 'culinary', 'work', 'experience', 'locally', 'abroad', 'decide', 'Open', 'mean', 'Since', 'serve', 'heart', 'food', 'meat', 'Loving', 'people', 'creation', 'deep', 'fry', 'burger', 'beaten', 'like', 'myburgerlab', 'define', 'burger', 'town', 'burger', 'fest', 'reason', 'visit', 'deep', 'fri', 'burger', 'ugly', 'wrap', 'special', 'bread', 'dough', 'g', 'mean', 'mine', 'patty', 'choiceof', 'either', 'beef', 'chicken', 'nest', 'caramelised', 'onion', 'top', 'healthy', 'help', 'melt', 'mozzarella', 'cheese', 'patty', 'good', 'juicy', 'juice', 'spill', 'bite', 'excellent', 'stuff', 'patty', 'melt', 'sandwich', 'bread', 'grill', 'cheese', 'house', 'chicken', 'beef', 'serve', 'pasteand', 'tomato', 'salsa', 'grill', 'cheese', 'add', 'good', 'story', 'touch', 'chicken', 'sandwich', 'chill', 'cheese', 'fry', 'serve', 'stainless', 'steel', 'latter', 'bed', 'fry', 'top', 'bolognese', 'style', 'chicken', 'melt', 'cheese', 'hit', 'young', 'one', 'couldnt', 'resist', 'take', 'Jalapeno', 'Peppers', 'leaded.peppers', 'stuff', 'spicy', 'cream', 'cheese', 'piece', 'price', 'side', 'make', 'good', 'version', 'spider', 'x', 'g', 'house', 'beef', 'patty', 'baby', 'run', 'melt', 'American', 'slice', 'cheese', 'top', 'pickle', 'red', 'onion', 'caramelise', 'onion', 'mustard', 'mayo', 'easy', 'kid', 'grab', 'Peanut', 'Butter', 'Milkshake', 'cant', 'get', 'American', 'classic', 'milkshake', 'like', 'burger', 'lover', 'deep', 'fried', 'burger', 'alone', 'could', 'warrant', 'trip', 'mean', 'since', 'member', 'family', 'eye', 'chicago', 'style', 'deep', 'dish', 'pizza', 'well', 'variation', 'burger', 'subsequent', 'visit', 'Excellent', 'Food', 'Excellent', 'Service', 'Good', 'Atmosphere', 'Recommended', 'Dishes', 'Chill', 'Cheese', 'Fries']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['look', 'rustic', 'nonsense', 'type', 'western', 'burger', 'reach', 'cheese', 'sauce', 'definitely', 'place', 'go', 'good', 'quality', 'meat', 'fluffy', 'roche', 'run', 'onion', 'ring', 'also', 'make', 'actual', 'proper', 'onion', 'process', 'pack', 'one', 'really', 'enjoyed', 'smash', 'definitely', 'back', 'try', 'philly', 'cheesesteak', 'excellent', 'food', 'excellent', 'service', 'good', 'atmosphere']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['burger', 'restaurant', 'locate', 'Tiara', 'Damansara', 'service', 'atmosphere', 'excellent', 'owner', 'personally', 'provide', 'great', 'service', 'patiently', 'introduce', 'signature', 'burger', 'main', 'dish', 'focus', 'burger', 'offer', 'great', 'selection', 'especially', 'love', 'innovation', 'bring', 'burger', 'Quality', 'meat', 'pair', 'soft', 'roche', 'run', 'onion', 'ring', 'make', 'real', 'onion', 'process', 'package', 'one', 'try', 'different', 'burger', 'create', 'rich', 'flavor', 'profile', 'also', 'order', 'peanut', 'butter', 'shake', 'taste', 'interest', 'sound', 'odd', 'super', '-flavorful', 'drink', 'Also', 'try', 'strawberry', 'milkshake', 'coke', 'float', 'here', "'s", 'ordered', 'burger', 'spider', 'Deep', 'Fried', 'Burger', 'Chi', 'Mean', 'Church', 'Peanut', 'Butter', 'Shake', 'Strawberry', 'Shake', 'Coke', 'Float', 'Overall', 'Rating', 'Food', 'Service', 'Audience', 'Excellent', 'Food', 'Excellent', 'Service', 'Good', 'Atmosphere', 'Recommended', 'Dishes', 'Beef', 'Burger']
#
#    compound    pos    neu    neg sentiment_label
# 0    0.9920  0.547  0.453  0.000        positive
# 1    0.9744  0.531  0.469  0.000        positive
# 2    0.9952  0.266  0.702  0.031        positive
# 3    0.9631  0.398  0.557  0.046        positive
# 4    0.9903  0.325  0.621  0.055        positive

# %%
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# Pie chart for sentiment distribution
sentiment_counts = df_vader['sentiment_label'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.title("Sentiment Distribution")
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Export the DataFrame to a new CSV file
output_file_path = "sentiment_analysis_reviews.csv"
df_vader.to_csv(output_file_path, index=False)

print(f"File saved as {output_file_path}")
# Out:
# File saved as sentiment_analysis_reviews.csv
