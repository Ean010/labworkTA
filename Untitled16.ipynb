# %%
# Import pandas
import pandas as pd

# Load the dataset
file_path = "combined_burgerreviews_tokenised_polished.csv"
df = pd.read_csv(file_path)

# Show available columns
print("Available columns:", df.columns.tolist())
# Out:
# Available columns: ['place_name', 'name', 'reviewer_profile', 'rating', 'review_text', 'published_at', 'published_at_date', 'total_number_of_photos_by_reviewer', 'lowercased', 'urls_removed', 'html_removed', 'emojis_removed', 'slangs_replaced', 'punctuations_removed', 'contractions_replaced', 'price_removed', 'autocorrected', 'mm_removed', 'translated', 'stopwords_removed', 'ratings_converted', 'numbers_removed', 'lemmatized', 'tokenized', 'translated_fixed']

# %%
pd.set_option('display.max_colwidth', None)  # Set to None for unlimited width

print(df)
# Out:
#              place_name            name  \
# 0            Mean Mince           SW K.
# 1            Mean Mince          J Soon
# 2            Mean Mince  Boon Loong Leo
# 3            Mean Mince   Matthew Nunis
# 4            Mean Mince    Suzanne Tham
# ...                 ...             ...
# 1121      Spades Burger             NaN
# 1122      Spades Burger             NaN
# 1123      Spades Burger             NaN
# 1124      Spades Burger             NaN
# 1125  Woodfire Kl @ttdi             NaN
#
#                                                                  reviewer_profile  \
# 0     https://www.google.com/maps/contrib/103839925189535627667/reviews?entry=ttu
# 1     https://www.google.com/maps/contrib/107730387208235308850/reviews?entry=ttu
# 2     https://www.google.com/maps/contrib/104227007256556386266/reviews?entry=ttu
# 3     https://www.google.com/maps/contrib/112715378443008140647/reviews?entry=ttu
# 4     https://www.google.com/maps/contrib/106659716325073081077/reviews?entry=ttu
# ...                                                                           ...
# 1121                                                                          NaN
# 1122                                                                          NaN
# 1123                                                                          NaN
# 1124                                                                          NaN
# 1125                                                                          NaN
#
#       rating  \
# 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
# ...      ...
# 1121     NaN
# 1122     NaN
# 1123     NaN
# 1124     NaN
# 1125     NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             review_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Love the double smash burger here. Bun is soft, patty crispy and still juicy, great flavours overall. The Philly cheesesteak was also good with very generous portion. Pizzas also were very generous with the toppings and cheesy. Milkshake was also thick not watery like some other places.\nAunty MM running the place was super friendly and accommodating. Parking is also plentiful which makes it's a super plus point.\nFood: 5/5 | Service: 5/5 | Atmosphere: 4/5
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        We had a lovely time having their burgers, buffalo wings and sliders. Our 5 year old had a super time trying their mini burgers.\n\nRun by a family, they were really friendly and the food was all freshly prepared! Will definitely recommend it\nFood: 5/5 | Service: 5/5 | Atmosphere: 5/5
# 2     I Will Always Love You by Bon Jovi was playing from the speakers as I pushed the door open to enter Mean Mince, an American concept restaurant serving burgers, sandwiches, milkshakes and other dishes in Mutiara Damansara.\n\nChef Min who studied in culinary and has working experience locally and abroad, has decided to open up Mean Mince to serve hearty food to the meat-loving people. His creation, deep fried burger, has beaten the likes of MyBurgerLab and Define:Burger during My Town Burger Fest in 2019 - the very reason of this visit.\n\nMM Deep Fried Burger RM23.90 - Snugly wrapped in special bread dough is a 125g Mean Minces patty with a choice of either beef or chicken, nestled with caramelised onions, and topped off with a healthy helping of melty mozzarella cheese. The patty was so good and juicy that the jus spilled out with each bite. Excellent stuff!\nPatty Melts RM27.90 - the sandwich bread was grilled with cheese; in-house chicken (or beef) served with pickled onions and tomato salsa. The grilled cheese added a good savory touch to this ch
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 1121                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['spade', '’', 's', 'pork', 'party', 'tasty', 'especially', 'like', 'cook', 'cheese', 'burger', 'make', 'go', 'burger', 'place', 'choose', 'burger', 'without', 'bun', 'wrap', 'lettuce', 'instead', 'must', 'try', 'love', 'pork', 'burger', 'read']
# 1122                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['first', 'time', 'taste', 'ipo', 'second', 'time', 'open', 'outlet', 's', 'sung', 'jay', 'although', 'kl', 'close', 'enough', 'staff', 'friendly', 'helpful', 'takeaway', 'time', 'place', 'easy', 'look', 'park', 'ordered', 'signature', 'big', 'burger', 'call', 'burger', 'steel', 'dozen', 'pocket', 'dozen', 'fry', 'bacon', 'strip', 'lunch', 'time', 'customer', 'din', 'pocket', 'actually', 'pork', 'nugget', 'item', 'order', 'really', 'good', 'come', 'back', 'surreal']
# 1123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['walk', 'pm', 'january', 'chinese', 'girl', 'counter', 'roll', 'eye', 'walk', 'away', 'check', 'huge', 'menu', 'wall', 'guy', 'come', 'cashier', 'stare', 'u', 'rude', 'facial', 'expression', 'order', 'burger', 'sound', 'really', 'unhappy', 'seriously', 'unhappy', 'come', 'late', 'hour', 'order', 'want', 'widely', 'ask', 'u', '“', 'what', 'combo', 'want', '”', 'mouth', 'cover', 'black', 'mask', 'really', 'hard', 'understand', 'say', 'ask', 'repeat', 'say', 'widely', 'ask', '“', 'what', 'combo', 'want', '”', 'want', 'piss', 'order', '“', 'all', 'pork', 'fine', '”', 'say', 'ask', 'u', 'another', 'question', 'combo', 'point', 'tv', 'menu', 'rally', 'rude', 'tone', 'st', 'it', '’', 's', 'break', 'hard', 'hear', 'mouth', 'cover', 'black', 'mask', 'nd', 'it', '’', 's', 'hard', 'understand', 'english', 'especially', 'sounded', 'angry', 'rd', 'it', '’', 's', 'close', 'disturb', 'closing', 'time', 'tel', 'u', 'it', '’', 's', 'close', 'win', '’', 't', 'torture', 'staff', 'rudeness', 'r', 'eat', 'free', 'didn', '’', 't', 'ask', 'anything', 'free', 'understand', 'rude', 'customer', 'also', 'retail', 'business', 'funny', 'thing', 'even', 'rude', 'worry', 'even', 'upset', 'can', 'not', 'handle', 'anymore', 'customer', 'put', 'closed', 'sign', 'read']
# 1124                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['non', 'halal', 'version', 'myburgerlab', 'opinion', 'gorgeous', 'ensemble', 'much', 'beauty', 'flavour', 'every', 'bite', 'regret', 'read']
# 1125                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['simple', 'decor', 'burger', 'joint', 'ttda', 'plaza', 'work', 'like', 'fast', 'food', 'joint', 'order', 'pay', 'wait', 'food', 'place', 'clean', 'service', 'friendly', 'order', 'beef', 'chicken', 'burger', 'surprise', 'burger', 'come', 'fry', 'fry', 'need', 'buy', 'separately', 'find', 'burger', 'tasty', 'money', 'sauce', 'delicious', 'side', 'also', 'compliment', 'burger', 'party', 'cook', 'well', 'chicken', 'crisp', 'outer', 'pretty', 'enjoyable', 'burger', 'mind', 'pay', 'extra', 'fry', 'read']
#
# [1126 rows x 25 columns]

# %%
def fast_tokenize(text):
    if isinstance(text, str):
        return text.split()
    return []

df["tokens"] = df["stopwords_removed"].apply(fast_tokenize)
print(df["tokens"])
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                     [love, double, smash, burger, bun, soft, patty, crispy, still, juicy, great, flavours, overall, philly, cheesesteak, also, good, generous, portion, pizzas, also, generous, toppings, cheesy, milkshake, also, thick, watery, like, places, aunty, mm, running, place, super, friendly, accommodating, parking, also, plentiful, makes, super, plus, point, excellent, food, excellent, service, good, atmosphere]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [non, halal, version, myburgerlab, opinion, gorgeous, ensembles, much, beauty, flavour, every, bite, regret, read]
# 1125                                                                                                                                                                                                                                                                                                                                                                                       [simple, decor, burger, joint, ttdi, plaza, works, like, fast, food, joint, order, paid, wait, foods, place, clean, service, friendly, ordered, beef, chicken, burgers, surprised, burger, come, fries, fries, need, buy, separately, find, burger, tasty, coney, sauce, delicious, sides, also, compliment, burgers, patties, cooked, well, chicken, crisp, outer, pretty, enjoyable, burger, mind, pay, extra, fries, read]
# Name: tokens, Length: 1126, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Assuming your cleaned text is in this column
texts = df["stopwords_removed"].astype(str)

# Create vectorizer and transform text
vectorizer = CountVectorizer()
X_bow = vectorizer.fit_transform(texts)

# Check shape
print(X_bow.shape)  # (num_docs, num_unique_words)
# Out:
# (1126, 5379)

# %%
# Get list of feature words
feature_names = vectorizer.get_feature_names_out()

# Example: show top 10 words
print(feature_names[:10])
# Out:
# ['00' '09' '10' '100' '1000' '10000' '100plus' '10mins' '10pm' '11']

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Load the dataset
df = pd.read_csv('combined_burgerreviews_tokenised_polished.csv')
# ------------------------
# 1. Bag of Words
# ------------------------
bow_vectorizer = CountVectorizer(max_features=5000)  # you can adjust max_features
bow_features = bow_vectorizer.fit_transform(texts)

# bow_features is a sparse matrix
print("BoW shape:", bow_features.shape)

# ------------------------
# 2. TF-IDF
# ------------------------
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
tfidf_features = tfidf_vectorizer.fit_transform(texts)

print("TF-IDF shape:", tfidf_features.shape)
# Out:
# BoW shape: (1126, 5000)
# TF-IDF shape: (1126, 5000)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Assuming you have a DataFrame called df
analyzer = SentimentIntensityAnalyzer()

# Apply VADER to the 'Text' column
def vader_sentiment(text):
    score = analyzer.polarity_scores(text)
    return score['compound']

df['vader_score'] = texts.apply(vader_sentiment)

# Assign sentiment based on compound score
def get_sentiment_label(score):
    if score >= 0.05:
        return 'positive'
    elif score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

df['vader_sentiment'] = df['vader_score'].apply(get_sentiment_label)

# %%
from textblob import TextBlob

# Apply TextBlob
def textblob_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['textblob_score'] = texts.apply(textblob_sentiment)

# Assign sentiment based on polarity
df['textblob_sentiment'] = df['textblob_score'].apply(lambda x: 'positive' if x > 0 
                                                      else 'negative' if x < 0 
                                                      else 'neutral')

# %%
# Create true sentiment label from score (e.g., 4-5 = pos, 1-2 = neg, 3 = neutral)
def get_label_from_score(rating):
    if rating >= 4:
        return 'positive'
    elif rating <= 2:
        return 'negative'
    else:
        return 'neutral'

df['true_sentiment'] = df['rating'].apply(get_label_from_score)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(texts)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

# Check how many NaN values are in the rating column
print(f"Number of NaN values in 'rating': {df['rating'].isna().sum()}")

# Option 1: Drop rows with NaN ratings
df_clean = df.dropna(subset=['rating'])
X_clean = X[df['rating'].notna()]  # Make sure X also has the same rows


# Train model on the cleaned dataset
model = MultinomialNB()
model.fit(X_clean, df_clean['rating'])

# Predict for all rows with features
y_pred = model.predict(X)

# Map predictions to sentiment labels
sentiment_mapping = {
    1: "negative",
    2: "negative",
    3: "neutral",
    4: "positive",
    5: "positive"
}
y_pred_mapped = [sentiment_mapping[label] for label in y_pred]

# Write predictions to a new column in the original DataFrame
df["nb_sentiment"] = y_pred_mapped

# Confirm everything is mapped
print("Unique Naive Bayes sentiment values after mapping:", df['nb_sentiment'].unique())
# Out:
# Number of NaN values in 'rating': 91
# Unique Naive Bayes sentiment values after mapping: ['positive']

# %%
# Then you can compute accuracy
from sklearn.metrics import accuracy_score, classification_report

print("Unique true_sentiment values:", df['true_sentiment'].unique())
print("Unique VADER sentiment values:", df['vader_sentiment'].unique())
print("Unique TextBlob sentiment values:", df['textblob_sentiment'].unique())
print("Unique Naive Bayes sentiment values:", df['nb_sentiment'].unique())

print("VADER Accuracy:", accuracy_score(df['true_sentiment'], df['vader_sentiment']))
print("TextBlob Accuracy:", accuracy_score(df['true_sentiment'], df['textblob_sentiment']))
print("Naive Bayes Accuracy:", accuracy_score(df['true_sentiment'], df['nb_sentiment']))
# Out:
# Unique true_sentiment values: ['positive' 'neutral' 'negative']
# Unique VADER sentiment values: ['positive' 'neutral' 'negative']
# Unique TextBlob sentiment values: ['positive' 'negative' 'neutral']
# Unique Naive Bayes sentiment values: ['positive']
# VADER Accuracy: 0.7655417406749556
# TextBlob Accuracy: 0.7682060390763765
# Naive Bayes Accuracy: 0.7380106571936057

# %%
tb_counts = df["textblob_sentiment"].value_counts()
vader_counts = df["vader_sentiment"].value_counts()
nb_counts = df["nb_sentiment"].value_counts()

import matplotlib.pyplot as plt

# First, check how many categories each sentiment analysis has
print(f"TextBlob categories: {len(tb_counts)}")
print(f"VADER categories: {len(vader_counts)}")
print(f"Naive Bayes categories: {len(nb_counts)}")

# Then create a pie chart with dynamically sized explode tuples
plt.figure(figsize=(15,5))

# TextBlob sentiment pie chart
plt.subplot(1,3,1)
plt.title("TextBlob Results")
# Create explode tuple of the right length, with only the last element exploded
tb_explode = [0] * (len(tb_counts) - 1) + [0.25]
plt.pie(tb_counts.values, labels=tb_counts.index, explode=tb_explode, autopct='%1.1f%%', shadow=False)

# VADER sentiment pie chart
plt.subplot(1,3,2)
plt.title("VADER Results")
vader_explode = [0] * (len(vader_counts) - 1) + [0.25]
plt.pie(vader_counts.values, labels=vader_counts.index, explode=vader_explode, autopct='%1.1f%%', shadow=False)

# Naive Bayes sentiment pie chart
plt.subplot(1,3,3)
plt.title("Naive Bayes Results")
nb_explode = [0] * (len(nb_counts) - 1) + [0.25]
plt.pie(nb_counts.values, labels=nb_counts.index, explode=nb_explode, autopct='%1.1f%%', shadow=False)

plt.tight_layout()
plt.show()
# Out:
# TextBlob categories: 3
# VADER categories: 3
# Naive Bayes categories: 1

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# TextBlob accuracy
tb_accuracy = accuracy_score(df["true_sentiment"], df["textblob_sentiment"])
print("TextBlob Accuracy:", round(tb_accuracy * 100, 2), "%")

# Full classification report
print("TextBlob Report:")
print(classification_report(df["true_sentiment"], df["textblob_sentiment"]))
# Out:
# TextBlob Accuracy: 76.82 %
# TextBlob Report:
#               precision    recall  f1-score   support
#
#     negative       0.55      0.63      0.59        95
#      neutral       0.11      0.01      0.02       200
#     positive       0.81      0.97      0.88       831
#
#     accuracy                           0.77      1126
#    macro avg       0.49      0.54      0.49      1126
# weighted avg       0.66      0.77      0.70      1126
